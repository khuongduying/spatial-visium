# %% [markdown]
# # SPATIAL TRANSCRIPTOMICS ANALYSIS FOR D1 SAMPLE

# %% [markdown]
# ## LOAD PACKAGES

# %%
# %%bash
# pip install scapy
# pip install anndata

# %%
import scanpy as sc
import squidpy as sq 
import anndata as ad 
import scipy as sp
import numpy as np

# %% [markdown]
# ## Convert SpaceRanger output to AnnData

# %%
# Specify the location
path_visium="/mnt/rdisk/duydao/scRNAseq/Spatial_transcriptomics/GeneSmart/output/D1/HTI_spaceranger_count_D1/outs"
h5ad_file="/mnt/rdisk/duydao/scRNAseq/Spatial_transcriptomics/GeneSmart/output/D1/HTI_spaceranger_count_D1/outs/filtered_feature_bc_matrix.h5"
image="/mnt/rdisk/duydao/scRNAseq/Spatial_transcriptomics/GeneSmart/output/D1/HTI_spaceranger_count_D1/outs/spatial/tissue_hires_image.png"

adata = sc.read_visium(path=path_visium,
                       genome="GRCh38",
                       count_file=h5ad_file,
                       load_images=True,
                       library_id="Visium_FFPE_Mouse_Brain_D1",
                       source_image_path=image)
# Out:
# /opt/miniconda/lib/python3.8/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/miniconda/lib/python3.8/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
# Specify the location
path_visium="/mnt/rdisk/duydao/scRNAseq/Spatial_transcriptomics/GeneSmart/output/D1/HTI_spaceranger_count_D1/outs"
h5ad_file="/mnt/rdisk/duydao/scRNAseq/Spatial_transcriptomics/GeneSmart/output/D1/HTI_spaceranger_count_D1/outs/filtered_feature_bc_matrix.h5"
image="/mnt/rdisk/duydao/scRNAseq/Spatial_transcriptomics/GeneSmart/output/D1/HTI_spaceranger_count_D1/outs/spatial/"

adata2 = sq.read.visium(path=path_visium,
                        counts_file=h5ad_file,
                        load_images=True,
                        library_id="Visium_FFPE_Mouse_Brain_D1",
                        source_image_path=image
                        )
# Out:
# /opt/miniconda/lib/python3.8/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/miniconda/lib/python3.8/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
#print(adata.var_names)
adata.var_names_make_unique()

adata2.var_names_make_unique()

# %%
print(adata2.uns['spatial'])
# Out:
# {'Visium_FFPE_Mouse_Brain_D1': {'metadata': {'chemistry_description': 'Visium V4 Slide', 'software_version': 'spaceranger-2.1.0', 'source_image_path': '/mnt/rdisk/duydao/scRNAseq/Spatial_transcriptomics/GeneSmart/output/D1/HTI_spaceranger_count_D1/outs/spatial'}, 'images': {'hires': array([[[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17]],
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17]],
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17]],
#
#        ...,
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17]],
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17]],
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17]]], dtype=uint8), 'lowres': array([[[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17]],
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17]],
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17]],
#
#        ...,
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17]],
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17]],
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17]]], dtype=uint8)}, 'scalefactors': {'regist_target_img_scalef': 1.0, 'tissue_hires_scalef': 0.8250825, 'tissue_lowres_scalef': 0.24752475, 'fiducial_diameter_fullres': 20.660621463341528, 'spot_diameter_fullres': 13.773747642227685}}}

# %%
adata.X
# Out:
# <3559x18085 sparse matrix of type '<class 'numpy.float32'>'
# 	with 21355822 stored elements in Compressed Sparse Row format>

# %%
# Test - Extract path in uns part
print(adata.uns['spatial'][library_names]["metadata"]["source_image_path"])
# Out:
# /mnt/rdisk/duydao/scRNAseq/Spatial_transcriptomics/GeneSmart/output/D1/HTI_spaceranger_count_D1/outs/spatial/tissue_hires_image.png

# %%
adata.uns['spatial']['library_id']="Visium_FFPE_Mouse_Brain_D1"
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 3559 × 18085
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
import re

# add info on mitochondrial and hemoglobin genes to the objects.
adata.var['mt'] = adata.var_names.str.contains('^MT', flags=re.IGNORECASE)
adata.var['hb'] = adata.var_names.str.contains("^HB", flags=re.IGNORECASE)

sc.pp.calculate_qc_metrics(adata, qc_vars=['mt','hb'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'total_counts_mt', 'total_counts_hb'],
             jitter=0.4, rotation= 45)

# %%
sc.pl.violin(adata, ['pct_counts_mt', 'pct_counts_hb'],
             jitter=0.4, rotation= 45)

# %%
adata.uns
print(adata.uns['spatial']['Visium_FFPE_Mouse_Brain_D1']['images']['hires'])
# Out:
# [[[0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   ...
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]]
#
#  [[0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   ...
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]]
#
#  [[0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   ...
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]]
#
#  ...
#
#  [[0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   ...
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]]
#
#  [[0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   ...
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]]
#
#  [[0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   ...
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]
#   [0.06666667 0.06666667 0.06666667]]]

# %%
# need to plot the two sections separately and specify the library_id

sc.pl.spatial(adata2)

# %%
sq.pl.spatial_scatter(adata2, 
                      spatial_key='spatial',
                      img=True, 
                      img_res_key='hires'
                      )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 sq.pl.spatial_scatter(adata2,
#       2                       spatial_key='spatial',
#       3                       img=True,
#       4                       img_res_key='hires'
#       5                       )
#
# File /opt/miniconda/lib/python3.8/site-packages/squidpy/pl/_spatial.py:418, in spatial_scatter(adata, shape, **kwargs)
#     377 @d.dedent
#     378 @_wrap_signature
#     379 def spatial_scatter(
#    (...)
#     382     **kwargs: Any,
#     383 ) -> Optional[Union[Axes, Sequence[Axes]]]:
#     384     """
#     385     Plot spatial omics data with data overlayed on top.
#     386
#    (...)
#     416     %(spatial_plot.returns)s
#     417     """
# --> 418     return _spatial_plot(adata, shape=shape, seg=None, seg_key=None, **kwargs)
#
# File /opt/miniconda/lib/python3.8/site-packages/squidpy/pl/_spatial.py:198, in _spatial_plot(adata, shape, color, groups, library_id, library_key, spatial_key, img, img_res_key, img_alpha, img_cmap, img_channel, seg, seg_key, seg_cell_id, seg_contourpx, seg_outline, use_raw, layer, alt_var, size, size_key, scale_factor, crop_coord, cmap, palette, alpha, norm, na_color, connectivity_key, edges_width, edges_color, library_first, frameon, wspace, hspace, ncols, outline, outline_color, outline_width, legend_loc, legend_fontsize, legend_fontweight, legend_fontoutline, legend_na, colorbar, scalebar_dx, scalebar_units, title, axis_label, fig, ax, return_ax, figsize, dpi, save, scalebar_kwargs, edges_kwargs, **kwargs)
#     168 color_params = _prepare_args_plot(
#     169     adata=adata,
#     170     shape=shape,
#    (...)
#     177     palette=palette,
#     178 )
#     180 spatial_params = _image_spatial_attrs(
#     181     adata=adata,
#     182     shape=shape,
#    (...)
#     195     img_cmap=img_cmap,
#     196 )
# --> 198 coords, crops = _set_coords_crops(
#     199     adata=adata,
#     200     spatial_params=spatial_params,
#     201     spatial_key=spatial_key,
#     202     crop_coord=crop_coord,
#     203 )
#     205 fig_params, cmap_params, scalebar_params, kwargs = _prepare_params_plot(
#     206     color_params=color_params,
#     207     spatial_params=spatial_params,
#    (...)
#     226     **kwargs,
#     227 )
#     229 for count, (_lib_count, value_to_plot) in enumerate(itertools.product(*fig_params.iter_panels)):
#
# File /opt/miniconda/lib/python3.8/site-packages/squidpy/pl/_spatial_utils.py:364, in _set_coords_crops(adata, spatial_params, spatial_key, crop_coord)
#     361     crops = [CropCoords(*cr) * sf for cr, sf in zip(crop_coord, spatial_params.scale_factor)]  # type: ignore[misc]
#     363 coords = adata.obsm[spatial_key]
# --> 364 return [coords * sf for sf in spatial_params.scale_factor], crops
#
# File /opt/miniconda/lib/python3.8/site-packages/squidpy/pl/_spatial_utils.py:364, in <listcomp>(.0)
#     361     crops = [CropCoords(*cr) * sf for cr, sf in zip(crop_coord, spatial_params.scale_factor)]  # type: ignore[misc]
#     363 coords = adata.obsm[spatial_key]
# --> 364 return [coords * sf for sf in spatial_params.scale_factor], crops
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
sc.pl.highest_expr_genes(adata, n_top=20)
